# %% [markdown]
# syntax : ye code ko correct way me likhne ka tarika hai
#
# sementic: ye code ka meaning hai ye basically correct logic par work karta hai

# %%
## basic syntax rules in python
## python is case sensitive

name= "Dheeraj"
Name="Gupta"
print(name, Name)
## python me capital or samll letter se fark padta hai
# Out:
# Dheeraj Gupta

# %% [markdown]
# Indentation

# %% [markdown]
# Indentation in Python is used to define the structure and hierarchy of the code. Unlike many other programming languages that use braces {} to delimit blocks of code, Python uses indentation to determine the grouping of statements. This means that all the statements within a block must be indented at the same level.

# %%
## indentation
age= 30
if (age > 28):
    print ("he is eleigible")
else:
    print("he is rejected")
# Out:
# he is eleigible

# %%
## line continuation : एक statement को multiple lines में लिखना बिना syntax error के

total = 1+2+3+4+5+6+\
4+5+6

print(total)
# Out:
# 36

# %%
## multiple statements on a single line

x= 5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
##Understand  Semnatics In Python
# variable assignment
age=32 ##age is an integer
name="Krish" ##name is a string

# %%
## Type Inference
variable=10
print(type(variable))
variable="Krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Code exmaples of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This ont print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
