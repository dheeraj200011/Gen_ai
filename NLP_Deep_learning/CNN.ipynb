# %% [markdown]
# CNN (Convolutional Neural Network)

# %% [markdown]
# CNN ek Deep Learning architecture hai jo mainly:
#
# Images,
# Videos,
# Pattern recognition

# %% [markdown]
# ANN (artificail neural network)
